# %% [markdown]
# <a href="https://colab.research.google.com/github/TimurDanilov1985/PYTHON_HOME_WORK/blob/master/Task44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Задание 44. В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#    whoAmI
# 0   robot
# 1   robot
# 2   human
# 3   robot
# 4   robot
# 5   robot
# 6   human
# 7   human
# 8   robot
# 9   human
# 10  robot
# 11  human
# 12  robot
# 13  robot
# 14  robot
# 15  human
# 16  human
# 17  human
# 18  human
# 19  human

# %%
pd.DataFrame({'human': data['whoAmI'] == 'human', 'robot': data['whoAmI'] == 'robot'}).astype(int).head(20)
# Out:
#     human  robot
# 0       0      1
# 1       0      1
# 2       1      0
# 3       0      1
# 4       0      1
# 5       0      1
# 6       1      0
# 7       1      0
# 8       0      1
# 9       1      0
# 10      0      1
# 11      1      0
# 12      0      1
# 13      0      1
# 14      0      1
# 15      1      0
# 16      1      0
# 17      1      0
# 18      1      0
# 19      1      0
